# %% [markdown]
# <a href="https://colab.research.google.com/github/azamh1011/Adv.Programming2024/blob/main/Hydrology_Lab_Graph_Work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
# Data
temperature = [0, 6, 10, 16]
do = [14.2, 12.3, 10.6, 9.4]

# %%
# Title and labels
plt.title('Temperature vs. Dissolved Oxygen')
plt.xlabel('Temperature (°C)')
plt.ylabel('DO (mg/L)')
# Out:
# Text(0, 0.5, 'DO (mg/L)')

# %%
# Display the plot
plt.grid(True)
plt.show()

# %%
# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(temperature, do, marker='o',
linestyle='-', color='b')
